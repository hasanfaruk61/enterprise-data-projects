# %%
import pandas as pd

from data_generator import generate_raw_data
from preprocessing import clean_data
from analytics import perform_analytics
from reporting import generate_report

# %%
# 1. Step: Generate Data
print("Step 1: Generating Raw Data...")
raw_df = generate_raw_data(500) # 500 row created

# 2. Step: Clean and Preprocess
print("Step 2: Preprocessing Data...")
clean_df = clean_data(raw_df)

# 3. Step: Analytics
print("Step 3: Running Analytics Engine...")
analyzed_df, analysis_results = perform_analytics(clean_df)

# 4. Step: Reporting
print("Step 4: Generating Final Report...")
report_text, metadata = generate_report(analyzed_df, analysis_results)

# DISPLAY REPORT
print(report_text)
# Out:
# Step 1: Generating Raw Data...
# Step 2: Preprocessing Data...
# Data cleaning and transforming is successfully completed
# Step 3: Running Analytics Engine...
# Step 4: Generating Final Report...
#
# ...
#         ENTERPRISE SALES INTELLIGENCE REPORT
# ...
#
#         FINANCIAL SUMMARY:
#         - Total Revenue: $1,663,659.87
#         - Sales Target Reached: True
#
#         GEOGRAPHICAL PERFORMANCE (City, Revenue):
#         - BEST: Chicago ($148,313.05)
#         - WORST: Austin ($49,159.74)
#
#         PRODUCT INSIGHTS:
#         - Most Profitable Product: EXTERNAL HARD DRIVE
#
#         RISK MANAGEMENT:
#         - System Status: Critical
#         - Action Required in: Indianapolis, New York City, Phoenix, San Diego, San Jose, Seattle
#
# ...
